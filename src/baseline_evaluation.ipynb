# %%
import seaborn
import pandas as pd
import seaborn as sns

# %%
df_18 = pd.read_csv("tmp_results/results_18_rois.csv")

# %%
df_116 = pd.read_csv("tmp_results/results_116_rois.csv")

# %%
df_18["nrois"]="18"
df_116["nrois"]="116"

# %%
df = pd.concat([df_18, df_116], axis=0)

# %%
sns.boxplot(data=df, x="nrois", y="accuracy")
# Out:
# <Axes: xlabel='nrois', ylabel='accuracy'>
